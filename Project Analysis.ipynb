# %%
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# %matplotlib inline

pd.set_option('display.max_columns', None)

# %%
cars = pd.read_csv("e_9-5-2019-no-sales-_9_4_2019public.csv")

cars.head(3)
# Out:
#    Model Year      Mfr Name                  Division     Carline  \
# 0        2019         Honda                     Acura         NSX
# 1        2019    FCA US LLC                ALFA ROMEO          4C
# 2        2019  aston martin  Aston Martin Lagonda Ltd  Vantage V8
#
#   Verify Mfr Cd  Index (Model Type Index)  Eng Displ  # Cyl Transmission  \
# 0           HNX                        41        3.5      6  Auto(AM-S9)
# 1           CRX                       403        1.8      4    Auto(AM6)
# 2           ASX                         3        4.0      8     Auto(S8)
#
#    City FE (Guide) - Conventional Fuel  Hwy FE (Guide) - Conventional Fuel  \
# 0                                   21                                  22
# 1                                   24                                  34
# 2                                   18                                  25
#
#    Comb FE (Guide) - Conventional Fuel  City Unadj FE - Conventional Fuel  \
# ...

# %%
c = ['Division','Mfr Name', 'Model Year', 'Carline', 'Verify Mfr Cd', '# Cyl', 'Transmission', 'City FE (Guide) - Conventional Fuel', 'Hwy FE (Guide) - Conventional Fuel', 'Comb FE (Guide) - Conventional Fuel', 'Oil Viscosity', 'Drive Desc']
cars = pd.read_csv("e_9-5-2019-no-sales-_9_4_2019public.csv", usecols = c)

cars.head(10)
# Out:
#    Model Year             Mfr Name                  Division  \
# 0        2019                Honda                     Acura
# 1        2019           FCA US LLC                ALFA ROMEO
# 2        2019         aston martin  Aston Martin Lagonda Ltd
# 3        2019  Volkswagen Group of                      Audi
# 4        2019                  BMW                       BMW
# 5        2019  Volkswagen Group of                   Bugatti
# 6        2019       General Motors                 Chevrolet
# 7        2019       General Motors                 Chevrolet
# 8        2019       General Motors                 Chevrolet
# 9        2019       General Motors                 Chevrolet
#
#                Carline Verify Mfr Cd  # Cyl Transmission  \
# 0                  NSX           HNX      6  Auto(AM-S9)
# 1                   4C           CRX      4    Auto(AM6)
# 2           Vantage V8           ASX      8     Auto(S8)
# 3  TT Roadster quattro           VGA      4  Auto(AM-S7)
# ...

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 12 columns):
# Model Year                             1259 non-null int64
# Mfr Name                               1259 non-null object
# Division                               1259 non-null object
# Carline                                1259 non-null object
# Verify Mfr Cd                          1259 non-null object
# # Cyl                                  1259 non-null int64
# Transmission                           1259 non-null object
# City FE (Guide) - Conventional Fuel    1259 non-null int64
# Hwy FE (Guide) - Conventional Fuel     1259 non-null int64
# Comb FE (Guide) - Conventional Fuel    1259 non-null int64
# Drive Desc                             1259 non-null object
# Oil Viscosity                          1259 non-null object
# dtypes: int64(5), object(7)
# memory usage: 118.1+ KB

# %%
cars.describe(include = ["O"])
# Out:
#               Mfr Name Division Carline Verify Mfr Cd Transmission  \
# count             1259     1259    1259          1259         1259
# unique              22       41     838            22           27
# top     General Motors     Ford  CAMARO           GMX     Auto(S8)
# freq               189       95       8           189          283
#
#              Drive Desc Oil Viscosity
# count              1259          1259
# unique                5            83
# top     All Wheel Drive          0W20
# freq                352           198

# %%
maker_counts = cars['Mfr Name'].value_counts()
maker_counts
# Out:
# General Motors          189
# BMW                     122
# Ford Motor Company      121
# Toyota                  101
# Mercedes-Benz            91
# FCA US LLC               91
# Porsche                  72
# Volkswagen Group of      69
# Nissan                   68
# Honda                    64
# Jaguar Land Rover L      63
# Hyundai                  55
# Kia                      34
# MAZDA                    23
# Subaru                   22
# Volvo                    20
# Mitsubishi Motors Co     16
# Maserati                 11
# Ferrari                  10
# Rolls-Royce               7
# aston martin              6
# Roush                     4
# Name: Mfr Name, dtype: int64

# %%
maker_counts.plot.bar()
plt.title("Car Makers Distribution")
plt.xlabel("car manufacturers")
plt.ylabel("# of Cars")
# Out:
# Text(0, 0.5, '# of Cars')

# %%
cars['City FE (Guide) - Conventional Fuel'].hist(bins = 25)
plt.title("City Fuel Milage")
plt.xlabel("miles per gallon")
plt.ylabel("# of cars")
# Out:
# Text(0, 0.5, '# of cars')

# %%
cars['Hwy FE (Guide) - Conventional Fuel'].hist(bins = 25)
plt.title("Highway Fuel Milage")
plt.xlabel("miles per gallon")
plt.ylabel("# of cars")
# Out:
# Text(0, 0.5, '# of cars')

# %%
cars['Comb FE (Guide) - Conventional Fuel'].hist(bins = 25)
plt.title("Combination Fuel Milage")
plt.xlabel("miles per gallon")
plt.ylabel("# of cars")
# Out:
# Text(0, 0.5, '# of cars')

# %%
cars['# Cyl'].hist(bins = 15)
plt.title("Number of Cylinder")
plt.xlabel("# of cylinders")
plt.ylabel("# of cars")
# Out:
# Text(0, 0.5, '# of cars')

# %%
trans_counts = cars['Transmission'].value_counts()
trans_counts
# Out:
# Auto(S8)        283
# Auto(S6)        163
# Manual(M6)      116
# Auto(A9)        101
# Auto(A8)         83
# Auto(A6)         81
# Auto(AM-S7)      70
# Auto(S10)        58
# Auto(AV)         50
# Auto(AM7)        36
# Auto(AV-S7)      30
# Auto(S7)         26
# Auto(S9)         25
# Auto(AV-S6)      21
# Manual(M7)       19
# Auto(A10)        15
# Auto(AM-S8)      15
# Auto(A7)         14
# Manual(M5)       14
# Auto(AM6)        10
# Auto(AV-S8)       9
# Auto(AV-S10)      6
# Auto(A5)          5
# Auto(AM-S6)       3
# Auto(S5)          3
# Auto(A4)          2
# Auto(AM-S9)       1
# Name: Transmission, dtype: int64

# %%
trans_counts.plot.bar()
plt.title("Transmission Distribution")
plt.xlabel("Type of transmission")
plt.ylabel("# of Cars")
# Out:
# Text(0, 0.5, '# of Cars')

# %%
sns.relplot(y ="Hwy FE (Guide) - Conventional Fuel", x = "City FE (Guide) - Conventional Fuel", hue = "Mfr Name", data = cars)
plt.title("City vs Highway Fuel Efficiency")
# Out:
# Text(0.5, 1, 'City vs Highway Fuel Efficiency')

# %%
sns.relplot(x ="# Cyl", y = "City FE (Guide) - Conventional Fuel", hue = "Mfr Name", data = cars)
plt.title("# of Cylinders relationship to fuel efficiency")
# Out:
# Text(0.5, 1, '# of Cylinders relationship to fuel efficiency')

# %%
g =sns.relplot(x ="Drive Desc", y = "City FE (Guide) - Conventional Fuel", hue = "Mfr Name", data = cars,size=2, aspect=2)
plt.title("Drive System relation to fuel efficiency")
# Out:
# Text(0.5, 1, 'Drive System relation to fuel efficiency')
